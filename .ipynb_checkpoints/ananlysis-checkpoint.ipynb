# %%
import pandas as pd
path="C:/Users/ragha/Downloads/analysis/earthquake_data_tsunami.csv"
df=pd.read_csv(path)
print(df)
# Out:
#      Unnamed: 0  magnitude  cdi  mmi  sig  nst   dmin   gap    depth  \
# 0             0        7.0    8    7  768  117  0.509  17.0   14.000
# 1             1        6.9    4    4  735   99  2.229  34.0   25.000
# 2             2        7.0    3    3  755  147  3.125  18.0  579.000
# 3             3        7.3    5    5  833  149  1.865  21.0   37.000
# 4             4        6.6    0    2  670  131  4.998  27.0  624.464
# ..          ...        ...  ...  ...  ...  ...    ...   ...      ...
# 777         777        7.7    0    8  912  427  0.000   0.0   60.000
# 778         778        6.9    5    7  745    0  0.000   0.0   36.400
# 779         779        7.1    0    7  776  372  0.000   0.0  103.000
# 780         780        6.8    0    5  711   64  0.000   0.0   33.000
# 781         781        7.5    0    7  865  324  0.000   0.0   33.000
#
#      latitude  longitude  Year  Month  tsunami
# 0     -9.7963    159.596  2022     11        1
# ...

# %%
df.head() #for first 5 rows
# Out:
#    magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0        7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 1        6.9    4    4  735   99  2.229  34.0   25.000   -4.9559    100.738
# 2        7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3        7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4        6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
#
#    Year  Month  tsunami
# 0  2022     11        1
# 1  2022     11        0
# 2  2022     11        1
# 3  2022     11        1
# 4  2022     11        1

# %%
df.tail()  # for last  rows
# Out:
#      magnitude  cdi  mmi  sig  nst  dmin  gap  depth  latitude  longitude  \
# 777        7.7    0    8  912  427   0.0  0.0   60.0   13.0490    -88.660
# 778        6.9    5    7  745    0   0.0  0.0   36.4   56.7744   -153.281
# 779        7.1    0    7  776  372   0.0  0.0  103.0  -14.9280    167.170
# 780        6.8    0    5  711   64   0.0  0.0   33.0    6.6310    126.899
# 781        7.5    0    7  865  324   0.0  0.0   33.0    6.8980    126.579
#
#      Year  Month  tsunami
# 777  2001      1        0
# 778  2001      1        0
# 779  2001      1        0
# 780  2001      1        0
# 781  2001      1        0

# %%
df.to_csv(path)  # this is to save the file

# %%
df.dtypes # to view the data type  used in the file
# Out:
# magnitude    float64
# cdi            int64
# mmi            int64
# sig            int64
# nst            int64
# dmin         float64
# gap          float64
# depth        float64
# latitude     float64
# longitude    float64
# Year           int64
# Month          int64
# tsunami        int64
# dtype: object

# %%
df.describe() # gve the statistical memory
# Out:
#         magnitude         cdi         mmi          sig         nst  \
# count  782.000000  782.000000  782.000000   782.000000  782.000000
# mean     6.941125    4.333760    5.964194   870.108696  230.250639
# std      0.445514    3.169939    1.462724   322.465367  250.188177
# min      6.500000    0.000000    1.000000   650.000000    0.000000
# 25%      6.600000    0.000000    5.000000   691.000000    0.000000
# 50%      6.800000    5.000000    6.000000   754.000000  140.000000
# 75%      7.100000    7.000000    7.000000   909.750000  445.000000
# max      9.100000    9.000000    9.000000  2910.000000  934.000000
#
#              dmin         gap       depth    latitude   longitude  \
# count  782.000000  782.000000  782.000000  782.000000  782.000000
# mean     1.325757   25.038990   75.883199    3.538100   52.609199
# std      2.218805   24.225067  137.277078   27.303429  117.898886
# min      0.000000    0.000000    2.700000  -61.848400 -179.968000
# ...

# %%
df.describe(include="all")
# Out:
#         magnitude         cdi         mmi          sig         nst  \
# count  782.000000  782.000000  782.000000   782.000000  782.000000
# mean     6.941125    4.333760    5.964194   870.108696  230.250639
# std      0.445514    3.169939    1.462724   322.465367  250.188177
# min      6.500000    0.000000    1.000000   650.000000    0.000000
# 25%      6.600000    0.000000    5.000000   691.000000    0.000000
# 50%      6.800000    5.000000    6.000000   754.000000  140.000000
# 75%      7.100000    7.000000    7.000000   909.750000  445.000000
# max      9.100000    9.000000    9.000000  2910.000000  934.000000
#
#              dmin         gap       depth    latitude   longitude  \
# count  782.000000  782.000000  782.000000  782.000000  782.000000
# mean     1.325757   25.038990   75.883199    3.538100   52.609199
# std      2.218805   24.225067  137.277078   27.303429  117.898886
# min      0.000000    0.000000    2.700000  -61.848400 -179.968000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  782 non-null    float64
#  1   cdi        782 non-null    int64
#  2   mmi        782 non-null    int64
#  3   sig        782 non-null    int64
#  4   nst        782 non-null    int64
#  5   dmin       782 non-null    float64
#  6   gap        782 non-null    float64
#  7   depth      782 non-null    float64
#  8   latitude   782 non-null    float64
#  9   longitude  782 non-null    float64
#  10  Year       782 non-null    int64
#  11  Month      782 non-null    int64
#  12  tsunami    782 non-null    int64
# dtypes: float64(6), int64(7)
# memory usage: 79.6 KB

# %%
df.columns # provide the columns
# Out:
# Index(['magnitude', 'cdi', 'mmi', 'sig', 'nst', 'dmin', 'gap', 'depth',
#        'latitude', 'longitude', 'Year', 'Month', 'tsunami'],
#       dtype='object')

# %%
import pandas as pd
path="C:/Users/ragha/Downloads/analysis/employee.xlsx"
df=pd.read_excel(path) # importing excel file
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
df.head()
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090

# %%
df.tail()
# Out:
#    ID     Name  Age  Salary                Email   Mobile No
# 0   1    Ragav   24   55000    ragav@example.com  9876543210
# 1   2   Kushal   25   60000   kushal@example.com  8765432109
# 2   3  Sandeep   26   52000  sandeep@example.com  9988776655
# 3   4     Guru   27   58000     guru@example.com  9123456780
# 4   5   Chirag   23   50000   chirag@example.com  9090909090

# %%
df.dtypes
# Out:
# ID            int64
# Name         object
# Age           int64
# Salary        int64
# Email        object
# Mobile No     int64
# dtype: object

# %%
df.describe()
# Out:
#              ID        Age        Salary     Mobile No
# count  5.000000   5.000000      5.000000  5.000000e+00
# mean   3.000000  25.000000  55000.000000  9.369024e+09
# std    1.581139   1.581139   4123.105626  5.347063e+08
# min    1.000000  23.000000  50000.000000  8.765432e+09
# 25%    2.000000  24.000000  52000.000000  9.090909e+09
# 50%    3.000000  25.000000  55000.000000  9.123457e+09
# 75%    4.000000  26.000000  58000.000000  9.876543e+09
# max    5.000000  27.000000  60000.000000  9.988777e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         5 non-null      int64
#  1   Name       5 non-null      object
#  2   Age        5 non-null      int64
#  3   Salary     5 non-null      int64
#  4   Email      5 non-null      object
#  5   Mobile No  5 non-null      int64
# dtypes: int64(4), object(2)
# memory usage: 372.0+ bytes

# %%
df.head(5)
# Out:
#    ID     Name  Age  Salary                Email   Mobile No
# 0   1    Ragav   24   55000    ragav@example.com  9876543210
# 1   2   Kushal   25   60000   kushal@example.com  8765432109
# 2   3  Sandeep   26   52000  sandeep@example.com  9988776655
# 3   4     Guru   27   58000     guru@example.com  9123456780
# 4   5   Chirag   23   50000   chirag@example.com  9090909090

# %%
headers=["card","emp_name","emp_age","emp_salary","em_email","emp_mob"]
df.columns=headers
df.head()
# Out:
#    card emp_name  emp_age  emp_salary             em_email     emp_mob
# 0     1    Ragav       24       55000    ragav@example.com  9876543210
# 1     2   Kushal       25       60000   kushal@example.com  8765432109
# 2     3  Sandeep       26       52000  sandeep@example.com  9988776655
# 3     4     Guru       27       58000     guru@example.com  9123456780
# 4     5   Chirag       23       50000   chirag@example.com  9090909090

# %%
df["emp_age"]=df["emp_age"]+1
df.head()
# Out:
#    card emp_name  emp_age  emp_salary             em_email     emp_mob
# 0     1    Ragav       25       55000    ragav@example.com  9876543210
# 1     2   Kushal       26       60000   kushal@example.com  8765432109
# 2     3  Sandeep       27       52000  sandeep@example.com  9988776655
# 3     4     Guru       28       58000     guru@example.com  9123456780
# 4     5   Chirag       24       50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
#    card emp_name  emp_age  emp_salary             em_email     emp_mob
# 0     1    Ragav       25       55000    ragav@example.com  9876543210
# 1     2   Kushal       26       60000   kushal@example.com  8765432109
# 2     3  Sandeep       27       52000  sandeep@example.com  9988776655
# 3     4     Guru       28       58000     guru@example.com  9123456780
# 4     5   Chirag       24       50000   chirag@example.com  9090909090

# %%
df["emp_age"]=df["emp_age"]-1
df.head()
# Out:
#    card emp_name  emp_age  emp_salary             em_email     emp_mob
# 0     1    Ragav       24       55000    ragav@example.com  9876543210
# 1     2   Kushal       25       60000   kushal@example.com  8765432109
# 2     3  Sandeep       26       52000  sandeep@example.com  9988776655
# 3     4     Guru       27       58000     guru@example.com  9123456780
# 4     5   Chirag       23       50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
#    card emp_name  emp_age  emp_salary             em_email     emp_mob
# 0     1    Ragav       24       55000    ragav@example.com  9876543210
# 1     2   Kushal       25       60000   kushal@example.com  8765432109
# 2     3  Sandeep       26       52000  sandeep@example.com  9988776655
# 3     4     Guru       27       58000     guru@example.com  9123456780
# 4     5   Chirag       23       50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
  df.head()
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
df.drop([5],axis=0)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
df.dropna()
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090

# %%
df.drop(columns=["Name"],axis=1).drop([4],axis=0)  #  to drop specific row with column
# Out:
#    ID   Age  Salary                Email   Mobile No
# 0   1  24.0   55000    ragav@example.com  9876543210
# 1   2  25.0   60000   kushal@example.com  8765432109
# 2   3  26.0   52000  sandeep@example.com  9988776655
# 3   4  27.0   58000     guru@example.com  9123456780
# 5   6   NaN   20000                  NaN  8584839594

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
df.dropna(subset=["Age"],axis=0)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090

# %%
# Out:
#    ID   Age  Salary                Email   Mobile No
# 0   1  24.0   55000    ragav@example.com  9876543210
# 1   2  25.0   60000   kushal@example.com  8765432109
# 2   3  26.0   52000  sandeep@example.com  9988776655
# 3   4  27.0   58000     guru@example.com  9123456780
# 5   6   NaN   20000                  NaN  8584839594

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
import numpy as np
df["Age"].replace(np.nan,22)
# Out:
# 0    24.0
# 1    25.0
# 2    26.0
# 3    27.0
# 4    23.0
# 5    22.0
# Name: Age, dtype: float64

# %%
df.head()
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
df["Age"]=df["Age"]/2

# %%
df.head()
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090

# %%
df.rename(columns={"Age":"Emp_age"})
# Out:
#    ID     Name  Emp_age  Salary                Email   Mobile No
# 0   1    Ragav     6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal     6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep     6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru     6.75   58000     guru@example.com  9123456780
# 4   5   Chirag     5.75   50000   chirag@example.com  9090909090
# 5   6    kumar      NaN   20000                  NaN  8584839594

# %%
df.dtypes
# Out:
# ID             int64
# Name          object
# Age          float64
# Salary         int64
# Email         object
# Mobile No      int64
# dtype: object

# %%
df.drop([5],axis=0)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
df.drop([5],axis=0)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090

# %%
df.rename(columns={"Emp_age":"Age"})
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
df.dtypes
# Out:
# ID             int64
# Name          object
# Age          float64
# Salary         int64
# Email         object
# Mobile No      int64
# dtype: object

# %%
df.drop([5],axis=0)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090

# %%
df.head(5)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090
# 5   6    kumar   NaN   20000                  NaN  8584839594

# %%
df.dropna(inplace=True)

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090

# %%
df["Age"].astype("int")
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    5
# Name: Age, dtype: int64

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  6.00   55000    ragav@example.com  9876543210
# 1   2   Kushal  6.25   60000   kushal@example.com  8765432109
# 2   3  Sandeep  6.50   52000  sandeep@example.com  9988776655
# 3   4     Guru  6.75   58000     guru@example.com  9123456780
# 4   5   Chirag  5.75   50000   chirag@example.com  9090909090

# %%
df["Age"]=df["Age"].astype("int")

# %%
print(df)
# Out:
#    ID     Name  Age  Salary                Email   Mobile No
# 0   1    Ragav    6   55000    ragav@example.com  9876543210
# 1   2   Kushal    6   60000   kushal@example.com  8765432109
# 2   3  Sandeep    6   52000  sandeep@example.com  9988776655
# 3   4     Guru    6   58000     guru@example.com  9123456780
# 4   5   Chirag    5   50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
path="C:/Users/ragha/Downloads/analysis/earthquake_data_tsunami.csv"
df=pd.read_csv(path)
print(df)
# Out:
#      Unnamed: 0  magnitude  cdi  mmi  sig  nst   dmin   gap    depth  \
# 0             0        7.0    8    7  768  117  0.509  17.0   14.000
# 1             1        6.9    4    4  735   99  2.229  34.0   25.000
# 2             2        7.0    3    3  755  147  3.125  18.0  579.000
# 3             3        7.3    5    5  833  149  1.865  21.0   37.000
# 4             4        6.6    0    2  670  131  4.998  27.0  624.464
# ..          ...        ...  ...  ...  ...  ...    ...   ...      ...
# 777         777        7.7    0    8  912  427  0.000   0.0   60.000
# 778         778        6.9    5    7  745    0  0.000   0.0   36.400
# 779         779        7.1    0    7  776  372  0.000   0.0  103.000
# 780         780        6.8    0    5  711   64  0.000   0.0   33.000
# 781         781        7.5    0    7  865  324  0.000   0.0   33.000
#
#      latitude  longitude  Year  Month  tsunami
# 0     -9.7963    159.596  2022     11        1
# ...

# %%
import pandas as pd
path="C:/Users/ragha/Downloads/analysis/employee.xlsx"
df=pd.read_excel(path) # importing excel file
print(df)
# Out:
#     ID     Name  Age  Salary                Email    Mobile No
# 0    1    Ragav   24   55000    ragav@example.com   9876543210
# 1    2   Kushal   25   60000   kushal@example.com   8765432109
# 2    3  Sandeep   26   52000  sandeep@example.com   9988776655
# 3    4     Guru   27   58000     guru@example.com   9123456780
# 4    5   Chirag   23   50000   chirag@example.com   9090909090
# 5    6    kumar   20   20000      kumar@gmail.com   8584839594
# 6    7    majnu   33   29999      majnu@gmail.com   8909388398
# 7    8    kujli   20   30000      kujli@gmail.com   8029374658
# 8    9    pawan   23   70000      pawan@gmail.com  90383464733
# 9   10   kumari   33   70000     kumari@gmail.com   9028372882
# 10  11   arnold   25   50000      anold@gmail.com   9373827232

# %%
df.drop([5],axis=0)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090

# %%
print(df)
# Out:
#     ID     Name  Age  Salary                Email    Mobile No
# 0    1    Ragav   24   55000    ragav@example.com   9876543210
# 1    2   Kushal   25   60000   kushal@example.com   8765432109
# 2    3  Sandeep   26   52000  sandeep@example.com   9988776655
# 3    4     Guru   27   58000     guru@example.com   9123456780
# 4    5   Chirag   23   50000   chirag@example.com   9090909090
# 5    6    kumar   20   20000      kumar@gmail.com   8584839594
# 6    7    majnu   33   29999      majnu@gmail.com   8909388398
# 7    8    kujli   20   30000      kujli@gmail.com   8029374658
# 8    9    pawan   23   70000      pawan@gmail.com  90383464733
# 9   10   kumari   33   70000     kumari@gmail.com   9028372882
# 10  11   arnold   25   50000      anold@gmail.com   9373827232

# %%
df.drop([5],axis=0,inplace=True)

# %%
print(df)
# Out:
#    ID     Name   Age  Salary                Email   Mobile No
# 0   1    Ragav  24.0   55000    ragav@example.com  9876543210
# 1   2   Kushal  25.0   60000   kushal@example.com  8765432109
# 2   3  Sandeep  26.0   52000  sandeep@example.com  9988776655
# 3   4     Guru  27.0   58000     guru@example.com  9123456780
# 4   5   Chirag  23.0   50000   chirag@example.com  9090909090

# %%
df.head()
# Out:
#    ID     Name  Age  Salary                Email   Mobile No
# 0   1    Ragav   24   55000    ragav@example.com  9876543210
# 1   2   Kushal   25   60000   kushal@example.com  8765432109
# 2   3  Sandeep   26   52000  sandeep@example.com  9988776655
# 3   4     Guru   27   58000     guru@example.com  9123456780
# 4   5   Chirag   23   50000   chirag@example.com  9090909090

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         11 non-null     int64
#  1   Name       11 non-null     object
#  2   Age        11 non-null     int64
#  3   Salary     11 non-null     int64
#  4   Email      11 non-null     object
#  5   Mobile No  11 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 660.0+ bytes

# %%
 #df["Salary"]=df["Salary"]/df["Salary"].max()

# %%
#min max method

#df["Salary"]=(df["Salary"]-df["Salary"].min())/(df["Salary"].max()-df["Salary"].min())

# %%
# Z score methiod /standard deviation method

# df["Salary"]=(df["Salary"]-df["Salary"].mean())/df["Salary"].std()

# %%
print(df)
# Out:
#     ID     Name  Age  Salary                Email    Mobile No
# 0    1    Ragav   24   55000    ragav@example.com   9876543210
# 1    2   Kushal   25   60000   kushal@example.com   8765432109
# 2    3  Sandeep   26   52000  sandeep@example.com   9988776655
# 3    4     Guru   27   58000     guru@example.com   9123456780
# 4    5   Chirag   23   50000   chirag@example.com   9090909090
# 5    6    kumar   20   20000      kumar@gmail.com   8584839594
# 6    7    majnu   33   29999      majnu@gmail.com   8909388398
# 7    8    kujli   20   30000      kujli@gmail.com   8029374658
# 8    9    pawan   23   70000      pawan@gmail.com  90383464733
# 9   10   kumari   33   70000     kumari@gmail.com   9028372882
# 10  11   arnold   25   50000      anold@gmail.com   9373827232

# %%
## nmeric to categorial
'''
import numpy as np
bins=np.linspace(min(df["Salary"]),max(df["Salary"]),4) '''

# %%
'''gr_name=["low","midd","high"]'''

# %%
'''df["Salary-binned"]=pd.cut(df["Salary"],bins,labels=gr_name,include_lowest=True)
'''

# %%
df.head()
# Out:
#    ID     Name  Age  Salary                Email   Mobile No Salary-binned
# 0   1    Ragav   24   55000    ragav@example.com  9876543210          high
# 1   2   Kushal   25   60000   kushal@example.com  8765432109          high
# 2   3  Sandeep   26   52000  sandeep@example.com  9988776655          midd
# 3   4     Guru   27   58000     guru@example.com  9123456780          high
# 4   5   Chirag   23   50000   chirag@example.com  9090909090          midd

# %%
# aategoral data to nueric
'''
pd.get_dummies(df["Salary"])
'''
# Out:
# '\npd.get_dummies(df["Salary"])\n'

# %%
df.describe()
# Out:
#               ID        Age        Salary     Mobile No
# count  11.000000  11.000000     11.000000  1.100000e+01
# mean    6.000000  25.363636  49545.363636  1.646858e+10
# std     3.316625   4.365151  16403.555604  2.452097e+10
# min     1.000000  20.000000  20000.000000  8.029375e+09
# 25%     3.500000  23.000000  40000.000000  8.837410e+09
# 50%     6.000000  25.000000  52000.000000  9.090909e+09
# 75%     8.500000  26.500000  59000.000000  9.625185e+09
# max    11.000000  33.000000  70000.000000  9.038346e+10

# %%
df.head(10)
# Out:
#    ID     Name  Age  Salary                Email    Mobile No
# 0   1    Ragav   24   55000    ragav@example.com   9876543210
# 1   2   Kushal   25   60000   kushal@example.com   8765432109
# 2   3  Sandeep   26   52000  sandeep@example.com   9988776655
# 3   4     Guru   27   58000     guru@example.com   9123456780
# 4   5   Chirag   23   50000   chirag@example.com   9090909090
# 5   6    kumar   20   20000      kumar@gmail.com   8584839594
# 6   7    majnu   33   29999      majnu@gmail.com   8909388398
# 7   8    kujli   20   30000      kujli@gmail.com   8029374658
# 8   9    pawan   23   70000      pawan@gmail.com  90383464733
# 9  10   kumari   33   70000     kumari@gmail.com   9028372882

# %%
'''
index=pd.Index(df["Age"])
index.value_counts()
'''
# Out:
# Age
# 25    2
# 20    2
# 23    2
# 33    2
# 24    1
# 26    1
# 27    1
# Name: count, dtype: int64

# %%
# boxplot
import seaborn as sns
sns.boxplot(x="Salary",y="Age",data=df)
# Out:
# <Axes: xlabel='Salary', ylabel='Age'>

# %%
# scatterplot

import matplotlib.pyplot as plt
x=df["Salary"]
y=df["Age"]
plt.scatter(x,y)
plt.title("scattered data")
plt.xlabel("Length")
plt.ylabel("width")
# Out:
# Text(0, 0.5, 'width')

# %%
import numpy as np
grp=df.groupby("Salary")

grp.aggregate(np.sum)
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_22320\2301215103.py:4: FutureWarning: The provided callable <function sum at 0x000001CBEA9FE7A0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp.aggregate(np.sum)
#         ID          Name  Age                              Email    Mobile No
# Salary
# 20000    6         kumar   20                    kumar@gmail.com   8584839594
# 29999    7         majnu   33                    majnu@gmail.com   8909388398
# 30000    8         kujli   20                    kujli@gmail.com   8029374658
# 50000   16  Chiragarnold   48  chirag@example.comanold@gmail.com  18464736322
# 52000    3       Sandeep   26                sandeep@example.com   9988776655
# 55000    1         Ragav   24                  ragav@example.com   9876543210
# 58000    4          Guru   27                   guru@example.com   9123456780
# ...

# %%
import numpy as np
grp=df.groupby(["Salary","Age"])

grp.aggregate(np.sum)
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_9064\1275113358.py:4: FutureWarning: The provided callable <function sum at 0x00000247C8A7A7A0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp.aggregate(np.sum)
#             ID     Name                Email    Mobile No
# Salary Age
# 20000  20    6    kumar      kumar@gmail.com   8584839594
# 29999  33    7    majnu      majnu@gmail.com   8909388398
# 30000  20    8    kujli      kujli@gmail.com   8029374658
# 50000  23    5   Chirag   chirag@example.com   9090909090
#        25   11   arnold      anold@gmail.com   9373827232
# 52000  26    3  Sandeep  sandeep@example.com   9988776655
# 55000  24    1    Ragav    ragav@example.com   9876543210
# 58000  27    4     Guru     guru@example.com   9123456780
# 60000  25    2   Kushal   kushal@example.com   8765432109
# ...

# %%
grp=df.groupby(["Salary","Age"],as_index=False)

grp.aggregate(np.sum)
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_22320\2048161202.py:3: FutureWarning: The provided callable <function sum at 0x000001CBEA9FE7A0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp.aggregate(np.sum)
#     Salary  Age  ID     Name                Email    Mobile No
# 0    20000   20   6    kumar      kumar@gmail.com   8584839594
# 1    29999   33   7    majnu      majnu@gmail.com   8909388398
# 2    30000   20   8    kujli      kujli@gmail.com   8029374658
# 3    50000   23   5   Chirag   chirag@example.com   9090909090
# 4    50000   25  11   arnold      anold@gmail.com   9373827232
# 5    52000   26   3  Sandeep  sandeep@example.com   9988776655
# 6    55000   24   1    Ragav    ragav@example.com   9876543210
# 7    58000   27   4     Guru     guru@example.com   9123456780
# 8    60000   25   2   Kushal   kushal@example.com   8765432109
# ...

# %%
grp.size()
# Out:
#     Salary  Age  size
# 0    20000   20     1
# 1    29999   33     1
# 2    30000   20     1
# 3    50000   23     1
# 4    50000   25     1
# 5    52000   26     1
# 6    55000   24     1
# 7    58000   27     1
# 8    60000   25     1
# 9    70000   23     1
# 10   70000   33     1

# %%
grp.count()
# Out:
#     Salary  Age  ID  Name  Email  Mobile No
# 0    20000   20   1     1      1          1
# 1    29999   33   1     1      1          1
# 2    30000   20   1     1      1          1
# 3    50000   23   1     1      1          1
# 4    50000   25   1     1      1          1
# 5    52000   26   1     1      1          1
# 6    55000   24   1     1      1          1
# 7    58000   27   1     1      1          1
# 8    60000   25   1     1      1          1
# 9    70000   23   1     1      1          1
# 10   70000   33   1     1      1          1

# %%
df.groupby("Salary")["Age"].unique()
# Out:
# Salary
# 20000        [20]
# 29999        [33]
# 30000        [20]
# 50000    [23, 25]
# 52000        [26]
# 55000        [24]
# 58000        [27]
# 60000        [25]
# 70000    [23, 33]
# Name: Age, dtype: object

# %%
import pandas as pd
df_20=pd.DataFrame({"s.no":[1,2,3,4,5,6],'A':['apple','ant','aero','ananas','alov','aunt'],'B':['ball','bat','baloon','bus','buddy','bro'],'C':['cst','cake','car','cow','count','cooli'],'D':['Dog','duck','donkey','dober','duke','deamon']})
print(df_20)
# Out:
#    s.no       A       B      C       D
# 0     1   apple    ball    cst     Dog
# 1     2     ant     bat   cake    duck
# 2     3    aero  baloon    car  donkey
# 3     4  ananas     bus    cow   dober
# 4     5    alov   buddy  count    duke
# 5     6    aunt     bro  cooli  deamon

# %%
df_20.pivot(index='A',columns='B',values='C')
# Out:
# B      ball baloon   bat    bro  buddy  bus
# A
# aero    NaN    car   NaN    NaN    NaN  NaN
# alov    NaN    NaN   NaN    NaN  count  NaN
# ananas  NaN    NaN   NaN    NaN    NaN  cow
# ant     NaN    NaN  cake    NaN    NaN  NaN
# apple   cst    NaN   NaN    NaN    NaN  NaN
# aunt    NaN    NaN   NaN  cooli    NaN  NaN

# %%
df_20.pivot(index='s.no',columns='A',values=['B','C'])
# Out:
#            B                                  C                            \
# A       aero   alov ananas  ant apple aunt aero   alov ananas   ant apple
# s.no
# 1        NaN    NaN    NaN  NaN  ball  NaN  NaN    NaN    NaN   NaN   cst
# 2        NaN    NaN    NaN  bat   NaN  NaN  NaN    NaN    NaN  cake   NaN
# 3     baloon    NaN    NaN  NaN   NaN  NaN  car    NaN    NaN   NaN   NaN
# 4        NaN    NaN    bus  NaN   NaN  NaN  NaN    NaN    cow   NaN   NaN
# 5        NaN  buddy    NaN  NaN   NaN  NaN  NaN  count    NaN   NaN   NaN
# 6        NaN    NaN    NaN  NaN   NaN  bro  NaN    NaN    NaN   NaN   NaN
#
#
# A      aunt
# s.no
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6     cooli

# %%
import numpy as np
nd=np.random
nd.seed(0)
import seaborn as sns
dat_unif=nd.rand(6,6)
print(dat_unif)
# Out:
# [[0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276 0.38344152 0.79172504 0.52889492]
#  [0.56804456 0.92559664 0.07103606 0.0871293  0.0202184  0.83261985]
#  [0.77815675 0.87001215 0.97861834 0.79915856 0.46147936 0.78052918]
#  [0.11827443 0.63992102 0.14335329 0.94466892 0.52184832 0.41466194]
#  [0.26455561 0.77423369 0.45615033 0.56843395 0.0187898  0.6176355 ]]

# %%
#het_map=sns.heatmap(dat_unif)
het_map=sns.heatmap(dat_unif,vmin=-1,vmax=1)
het_map=sns.heatmap(dat_unif,center=0)

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot(index="month", columns="year", values="passengers")
heap_map4 = sns.heatmap(flights)

# %%
heap_map4 = sns.heatmap(flights,annot=True,fmt="d")
#heap_map4 = sns.heatmap(flights,annot=True,fmt="1f")

# %%
heat_map9=sns.heatmap(flights,cmap="RdBu")

# %%
heat_map9=sns.heatmap(flights,cmap="YlGnBu")

# %%
heat_map=sns.heatmap(flights,cbar=False)

# %%
flights = sns.load_dataset("flights")
sns.regplot(x="passengers",y="year",data=flights)
# Out:
# <Axes: xlabel='passengers', ylabel='year'>

# %%
from scipy import stats
flights = sns.load_dataset("flights")
print(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
pearson_correlation=stats.pearsonr(flights["year"],flights["passengers"])
print(pearson_correlation)
# Out:
# PearsonRResult(statistic=np.float64(0.92182383529242), pvalue=np.float64(2.58104255191102e-60))

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
x=flights[['year']]
y=flights['passengers']

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
Howsat=lm.predict(x)

# %%
print(Howsat)
# Out:
# [104.71688034 104.71688034 104.71688034 104.71688034 104.71688034
#  104.71688034 104.71688034 104.71688034 104.71688034 104.71688034
#  104.71688034 104.71688034 136.64083139 136.64083139 136.64083139
#  136.64083139 136.64083139 136.64083139 136.64083139 136.64083139
#  136.64083139 136.64083139 136.64083139 136.64083139 168.56478244
#  168.56478244 168.56478244 168.56478244 168.56478244 168.56478244
#  168.56478244 168.56478244 168.56478244 168.56478244 168.56478244
#  168.56478244 200.48873349 200.48873349 200.48873349 200.48873349
#  200.48873349 200.48873349 200.48873349 200.48873349 200.48873349
#  200.48873349 200.48873349 200.48873349 232.41268454 232.41268454
#  232.41268454 232.41268454 232.41268454 232.41268454 232.41268454
#  232.41268454 232.41268454 232.41268454 232.41268454 232.41268454
#  264.33663559 264.33663559 264.33663559 264.33663559 264.33663559
#  264.33663559 264.33663559 264.33663559 264.33663559 264.33663559
# ...

# %%
lm.intercept_
# Out:
# np.float64(-62115.06371406373)

# %%
lm.coef_
# Out:
# array([31.92395105])

# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\ragha\\Downloads\\analysis\\employee.xlsx")
print(df)
# Out:
#     ID     Name  Age  Salary                Email    Mobile No  num1  num2  \
# 0    1    Ragav   24   55000    ragav@example.com   9876543210     1    23
# 1    2   Kushal   25   60000   kushal@example.com   8765432109     2    33
# 2    3  Sandeep   26   52000  sandeep@example.com   9988776655     3    21
# 3    4     Guru   27   58000     guru@example.com   9123456780     4    22
# 4    5   Chirag   23   50000   chirag@example.com   9090909090     5    12
# 5    6    kumar   20   20000      kumar@gmail.com   8584839594     6    11
# 6    7    majnu   33   29999      majnu@gmail.com   8909388398     8    21
# 7    8    kujli   20   30000      kujli@gmail.com   8029374658    34    44
# 8    9    pawan   23   70000      pawan@gmail.com  90383464733    11    15
# 9   10   kumari   33   70000     kumari@gmail.com   9028372882    12    18
# 10  11   arnold   25   50000      anold@gmail.com   9373827232    44    19
#
#      num3
# 0   12.00
# 1   14.30
# 2   14.50
# 3   11.00
# ...

# %%
df.head()
# Out:
#    ID     Name  Age  Salary                Email   Mobile No  num1  num2  num3
# 0   1    Ragav   24   55000    ragav@example.com  9876543210     1    23  12.0
# 1   2   Kushal   25   60000   kushal@example.com  8765432109     2    33  14.3
# 2   3  Sandeep   26   52000  sandeep@example.com  9988776655     3    21  14.5
# 3   4     Guru   27   58000     guru@example.com  9123456780     4    22  11.0
# 4   5   Chirag   23   50000   chirag@example.com  9090909090     5    12   1.5

# %%
df.describe()
# Out:
#               ID        Age        Salary     Mobile No       num1       num2  \
# count  11.000000  11.000000     11.000000  1.100000e+01  11.000000  11.000000
# mean    6.000000  25.363636  49545.363636  1.646858e+10  11.818182  21.727273
# std     3.316625   4.365151  16403.555604  2.452097e+10  14.055733   9.498325
# min     1.000000  20.000000  20000.000000  8.029375e+09   1.000000  11.000000
# 25%     3.500000  23.000000  40000.000000  8.837410e+09   3.500000  16.500000
# 50%     6.000000  25.000000  52000.000000  9.090909e+09   6.000000  21.000000
# 75%     8.500000  26.500000  59000.000000  9.625185e+09  11.500000  22.500000
# max    11.000000  33.000000  70000.000000  9.038346e+10  44.000000  44.000000
#
#             num3
# count  11.000000
# mean   14.830000
# std     6.970961
# min     1.500000
# 25%    12.765000
# 50%    14.500000
# 75%    15.950000
# max    31.100000

# %%
df.dtypes
# Out:
# ID             int64
# Name          object
# Age            int64
# Salary         int64
# Email         object
# Mobile No      int64
# num1           int64
# num2           int64
# num3         float64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
#def variable
x=df[['num1','num2','num3']]
y=df['Age']

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
yath=lm.predict(x)

# %%
print(yath)
# Out:
# [25.78284489 25.27095225 25.80033064 25.68801331 26.06988373 26.13622396
#  25.58160045 23.30390618 25.80985627 25.53186484 24.02452346]

# %%
lm.intercept_
# Out:
# np.float64(26.864837266115167)

# %%
lm.coef_
# Out:
# array([-0.04577637, -0.04784051,  0.00534298])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x="Age",y="Salary",data=df)
plt.ylim(0,90000)
# Out:
# (0.0, 90000.0)

# %%
print(df)
# Out:
#     ID     Name  Age  Salary                Email    Mobile No  num1  num2  \
# 0    1    Ragav   24   55000    ragav@example.com   9876543210     1    23
# 1    2   Kushal   25   60000   kushal@example.com   8765432109     2    33
# 2    3  Sandeep   26   52000  sandeep@example.com   9988776655     3    21
# 3    4     Guru   27   58000     guru@example.com   9123456780     4    22
# 4    5   Chirag   23   50000   chirag@example.com   9090909090     5    12
# 5    6    kumar   20   20000      kumar@gmail.com   8584839594     6    11
# 6    7    majnu   33   29999      majnu@gmail.com   8909388398     8    21
# 7    8    kujli   20   30000      kujli@gmail.com   8029374658    34    44
# 8    9    pawan   23   70000      pawan@gmail.com  90383464733    11    15
# 9   10   kumari   33   70000     kumari@gmail.com   9028372882    12    18
# 10  11   arnold   25   50000      anold@gmail.com   9373827232    44    19
#
#      num3
# 0   12.00
# 1   14.30
# 2   14.50
# 3   11.00
# ...

# %%
import seaborn as sns
sns.residplot(x=df['Age'],y=df['Salary'])
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
import seaborn as sns
import numpy as np
df_23=sns.load_dataset("flights")

# %%
print(df_23)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df_23=df_23.pivot(index="month",columns="year",values="passengers")

# %%
print(df_23)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
df_23.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
import seaborn as sns
import numpy as np
np.random.seed(0)
x=np.random.rand(100)

# %%
print(x)
# Out:
# [0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411
#  0.43758721 0.891773   0.96366276 0.38344152 0.79172504 0.52889492
#  0.56804456 0.92559664 0.07103606 0.0871293  0.0202184  0.83261985
#  0.77815675 0.87001215 0.97861834 0.79915856 0.46147936 0.78052918
#  0.11827443 0.63992102 0.14335329 0.94466892 0.52184832 0.41466194
#  0.26455561 0.77423369 0.45615033 0.56843395 0.0187898  0.6176355
#  0.61209572 0.616934   0.94374808 0.6818203  0.3595079  0.43703195
#  0.6976312  0.06022547 0.66676672 0.67063787 0.21038256 0.1289263
#  0.31542835 0.36371077 0.57019677 0.43860151 0.98837384 0.10204481
#  0.20887676 0.16130952 0.65310833 0.2532916  0.46631077 0.24442559
#  0.15896958 0.11037514 0.65632959 0.13818295 0.19658236 0.36872517
#  0.82099323 0.09710128 0.83794491 0.09609841 0.97645947 0.4686512
#  0.97676109 0.60484552 0.73926358 0.03918779 0.28280696 0.12019656
#  0.2961402  0.11872772 0.31798318 0.41426299 0.0641475  0.69247212
# ...

# %%
ax_1=sns.distplot(x)
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_9064\400993501.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_1=sns.distplot(x)

# %%
ax_1=sns.distplot(x,rug=True,hist=False)
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_9064\2463607244.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_1=sns.distplot(x,rug=True,hist=False)

# %%
from scipy.stats import norm
ax_1=sns.distplot(x,fit=norm)
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_9064\3034709899.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_1=sns.distplot(x,fit=norm)

# %%
ax_1=sns.distplot(x,fit=norm,kde=False)
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_9064\3569753378.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_1=sns.distplot(x,fit=norm,kde=False)

# %%
sns.distplot(x,fit=norm)
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_9064\2392121712.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x,fit=norm)
# <Axes: ylabel='Density'>

# %%
ax_4=sns.distplot(x,vertical=True)
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_9064\1520317371.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_4=sns.distplot(x,vertical=True)

# %%
sns.set_color_codes()
ax_5=sns.distplot(x,color="r")
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_9064\1939102414.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_5=sns.distplot(x,color="r")

# %%
sns.set(style="dark")
sns.set_color_codes()
as_6=sns.distplot(x,color="g")
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_9064\1354152276.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   as_6=sns.distplot(x,color="g")

# %%
sns.lineplot(x)
# Out:
# <Axes: >

# %%
sns.countplot(df['Age'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.swarmplot(df["Salary"])
# Out:
# <Axes: ylabel='Salary'>

# %%
import numpy as np
x=df["Age"]
y=df["Salary"]
val=np.polyfit(x,y,2)#order 1.2.3.4.....
p=np.poly1d(val)

# %%
print(p)
# Out:
#         2
# -518.5 x + 2.9e+04 x - 3.434e+05

# %%
from sklearn.preprocessing import PolynomialFeatures
import seaborn as sns
flights=sns.load_dataset("flights")
pr=PolynomialFeatures(degree=2,include_bias=True)
x_Poly=pr.fit_transform(flights[['year','passengers']])
print(x_Poly)
# Out:
# [[1.000000e+00 1.949000e+03 1.120000e+02 3.798601e+06 2.182880e+05
#   1.254400e+04]
#  [1.000000e+00 1.949000e+03 1.180000e+02 3.798601e+06 2.299820e+05
#   1.392400e+04]
#  [1.000000e+00 1.949000e+03 1.320000e+02 3.798601e+06 2.572680e+05
#   1.742400e+04]
#  [1.000000e+00 1.949000e+03 1.290000e+02 3.798601e+06 2.514210e+05
#   1.664100e+04]
#  [1.000000e+00 1.949000e+03 1.210000e+02 3.798601e+06 2.358290e+05
#   1.464100e+04]
#  [1.000000e+00 1.949000e+03 1.350000e+02 3.798601e+06 2.631150e+05
#   1.822500e+04]
#  [1.000000e+00 1.949000e+03 1.480000e+02 3.798601e+06 2.884520e+05
#   2.190400e+04]
#  [1.000000e+00 1.949000e+03 1.480000e+02 3.798601e+06 2.884520e+05
#   2.190400e+04]
#  [1.000000e+00 1.949000e+03 1.360000e+02 3.798601e+06 2.650640e+05
#   1.849600e+04]
#  [1.000000e+00 1.949000e+03 1.190000e+02 3.798601e+06 2.319310e+05
#   1.416100e+04]
#  [1.000000e+00 1.949000e+03 1.040000e+02 3.798601e+06 2.026960e+05
#   1.081600e+04]
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(df["Age"],df["num1"],multioutput='raw_values')
# Out:
# array([400.27272727])

# %%
print(df)
# Out:
#     ID     Name  Age  Salary                Email    Mobile No  num1  num2  \
# 0    1    Ragav   24   55000    ragav@example.com   9876543210     1    23
# 1    2   Kushal   25   60000   kushal@example.com   8765432109     2    33
# 2    3  Sandeep   26   52000  sandeep@example.com   9988776655     3    21
# 3    4     Guru   27   58000     guru@example.com   9123456780     4    22
# 4    5   Chirag   23   50000   chirag@example.com   9090909090     5    12
# 5    6    kumar   20   20000      kumar@gmail.com   8584839594     6    11
# 6    7    majnu   33   29999      majnu@gmail.com   8909388398     8    21
# 7    8    kujli   20   30000      kujli@gmail.com   8029374658    34    44
# 8    9    pawan   23   70000      pawan@gmail.com  90383464733    11    15
# 9   10   kumari   33   70000     kumari@gmail.com   9028372882    12    18
# 10  11   arnold   25   50000      anold@gmail.com   9373827232    44    19
#
#      num3
# 0   12.00
# 1   14.30
# 2   14.50
# 3   11.00
# ...

# %%
mean_squared_error(df["Age"],df["num1"])
# Out:
# 400.27272727272725

# %%
x=flights[['year']]
y=flights[['passengers']]

# %%
ml=LinearRegression()

# %%
ml.fit(x,y)
# Out:
# LinearRegression()

# %%
ml.score(x,y)
# Out:
# 0.8497591833132266
